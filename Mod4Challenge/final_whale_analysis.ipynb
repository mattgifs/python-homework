# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns = Path('Resources/whale_returns.csv')
whale_returns_df = pd.read_csv(whale_returns)
whale_returns_df.head(3)
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213

# %%
# Count nulls
whale_returns_df.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df = whale_returns_df.dropna().copy()
whale_returns_df.head(3)
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726

# %%
# Set Index to date
#set Date as df index, inferring datetime format
whale_returns_df.set_index(pd.to_datetime(whale_returns_df['Date'], infer_datetime_format=True),inplace=True)

#drop extra date column
whale_returns_df.drop(columns=['Date'],inplace=True)

#check above
whale_returns_df.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns = Path('Resources/algo_returns.csv')
algo_returns_df = pd.read_csv(algo_returns)
algo_returns_df.head(3)
# Out:
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df = algo_returns_df.dropna().copy()
algo_returns_df.head(3)
# Out:
#          Date    Algo 1    Algo 2
# 6  2014-06-05  0.004062  0.013285
# 7  2014-06-06  0.001857  0.008284
# 8  2014-06-09 -0.005012  0.005668

# %%
# Set Index to date
#set Date as df index, inferring datetime format
algo_returns_df.set_index(pd.to_datetime(algo_returns_df['Date'], infer_datetime_format=True),inplace=True)

#drop extra date column
algo_returns_df.drop(columns=['Date'],inplace=True)

#check above
algo_returns_df.head(3)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_close_prices = Path('Resources/sp500_history.csv')
sp500_close_df = pd.read_csv(sp500_close_prices)
sp500_close_df.head(3)
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03

# %%
# Check Data Types
sp500_close_df.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types

#remove $ notation from Close, then cast Close asfloat
sp500_close_df['Close'] = sp500_close_df['Close'].str.replace('$','')
sp500_close_df['Close'] = sp500_close_df['Close'].astype('float')
sp500_close_df['Close']
# Out:
# C:\Users\giffo\AppData\Local\Temp\ipykernel_4596\3900962007.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_close_df['Close'] = sp500_close_df['Close'].str.replace('$','')
# 0       2933.68
# 1       2907.97
# 2       2905.03
# 3       2900.45
# 4       2907.06
#          ...
# 1644    1460.93
# 1645    1461.40
# 1646    1450.99
# 1647    1445.75
# 1648    1444.49
# Name: Close, Length: 1649, dtype: float64

# %%
# Fix Data Types (contd)

#set Date as df index, inferring datetime format
sp500_close_df.set_index(pd.to_datetime(sp500_close_df['Date'], infer_datetime_format=True),inplace=True)

#drop extra date column
sp500_close_df.drop(columns=['Date'],inplace=True)

# %%
sp500_close_df.head(3)
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03

# %%
# Sort sp500Close dataframe in ascending order to ensure proper pct_change calc in next step 
sp500_close_df = sp500_close_df.sort_index(ascending=True)

# Calculate Daily Returns
sp500_returns_df = sp500_close_df.pct_change()
sp500_returns_df
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp500_returns_df = sp500_returns_df.dropna().copy()
sp500_returns_df.head(3)
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns_df.columns = ['S&P 500 Returns']
sp500_returns_df.head(3)
# Out:
#             S&P 500 Returns
# Date
# 2012-10-02         0.000872
# 2012-10-03         0.003624
# 2012-10-04         0.007174

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
all_returns_df = pd.concat([whale_returns_df,algo_returns_df,sp500_returns_df],axis = 'columns',join = 'inner')
all_returns_df.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
#
#               Algo 2  S&P 500 Returns
# Date
# 2015-03-03 -0.000949        -0.004539
# 2015-03-04  0.002416        -0.004389
# 2015-03-05  0.004323         0.001196

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_returns_df.plot(title = 'Daily Returns for All Portfolios',figsize=(13,6))
# Out:
# <Axes: title={'center': 'Daily Returns for All Portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns_df = (1 + all_returns_df).cumprod() - 1

# Plot cumulative returns
cumulative_returns_df.plot(figsize=(12,6), title=('Cumulative Returns for All Portfolios'))
# Out:
# <Axes: title={'center': 'Cumulative Returns for All Portfolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
all_returns_df.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

# Create dataframe based on std calcs on the all_returns_df, set column name to StDev
portfolio_std_df = pd.DataFrame(all_returns_df.std(),columns=['StDev'])
#Rename index column to be descriptive
portfolio_std_df.index.name = 'Firm'
#Check
portfolio_std_df
# Out:
#                                 StDev
# Firm
# SOROS FUND MANAGEMENT LLC    0.007895
# PAULSON & CO.INC.            0.007023
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919
# Algo 1                       0.007620
# Algo 2                       0.008342
# S&P 500 Returns              0.008554

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate the daily standard deviation of S&P 500
sp500_std = portfolio_std_df.loc['S&P 500 Returns']
sp500_std

# Determine which portfolios are riskier than the S&P 500, and display
#portfolio_std_df.columns = ['Riskier than S&P 500?']
print('Firms with riskier returns than S&P500 will show TRUE')

portfolio_std_df > sp500_std
# Out:
# Firms with riskier returns than S&P500 will show TRUE
#                              StDev
# Firm
# SOROS FUND MANAGEMENT LLC    False
# PAULSON & CO.INC.            False
# TIGER GLOBAL MANAGEMENT LLC   True
# BERKSHIRE HATHAWAY INC        True
# Algo 1                       False
# Algo 2                       False
# S&P 500 Returns              False

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
ann_portfolio_std_df = portfolio_std_df * np.sqrt(252)
ann_portfolio_std_df
# Out:
#                                 StDev
# Firm
# SOROS FUND MANAGEMENT LLC    0.125335
# PAULSON & CO.INC.            0.111488
# TIGER GLOBAL MANAGEMENT LLC  0.172936
# BERKSHIRE HATHAWAY INC       0.205077
# Algo 1                       0.120967
# Algo 2                       0.132430
# S&P 500 Returns              0.135786

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
roll_std_df = all_returns_df.rolling(window=21).std()
# Plot the rolling standard deviation
roll_std_df.plot(figsize = (15,8), title='21Day Rolling StDev of All Portfolios')
# Out:
# <Axes: title={'center': '21Day Rolling StDev of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_correlation = all_returns_df.corr()

# Import Seaborn for use with correlation heatmap
import seaborn as sns

# Display de correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
## CHOOSING ALGO 1

# Calculate covariance of a single portfolio
algo_1_cov = all_returns_df['Algo 1'].cov(all_returns_df['S&P 500 Returns'])

# Calculate variance of S&P 500
sp500_var = all_returns_df['S&P 500 Returns'].var()

# Computing beta (cov/var = beta)
algo_1_beta = algo_1_cov / sp500_var
algo_1_beta

## Plot beta trend
#Calc rolling cov and var
rolling_algo_1_cov = all_returns_df['Algo 1'].rolling(window=21).cov(all_returns_df['S&P 500 Returns'])
rolling_sp500_var = all_returns_df['S&P 500 Returns'].rolling(window=21).var()

#Calc rolling beta and plot
rolling_algo_1_beta = rolling_algo_1_cov / rolling_sp500_var
rolling_algo_1_beta.plot(title = '21Day Rolling Beta of Algo 1 Portfolio',figsize = (13,8))
# Out:
# <Axes: title={'center': '21Day Rolling Beta of Algo 1 Portfolio'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
all_returns_df.ewm(halflife=21).std().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
##ADDING RISK FREE RATE DATA FOR SHARPE CALCS

# Read risk-free rate data from Resource dir
rfr = Path('Resources/risk_free_rate.csv')

#add rfr data to new df
rfr_df = pd.read_csv(rfr)

#set Date as df index, inferring datetime format
rfr_df.set_index(pd.to_datetime(rfr_df['Date'], infer_datetime_format=True),inplace=True)

#drop extra date column
rfr_df.drop(columns=['Date'],inplace=True)

#Make data column more readable
rfr_df.columns = ['Risk-Free Rate']

#Add to all_returns_df
rfr_and_all_returns_df = pd.concat([all_returns_df,rfr_df],axis = 'columns',join = 'inner')
rfr_and_all_returns_df.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
#
#               Algo 2  S&P 500 Returns  Risk-Free Rate
# Date
# 2015-03-03 -0.000949        -0.004539        0.000002
# 2015-03-04  0.002416        -0.004389        0.000001
# 2015-03-05  0.004323         0.001196        0.000002

# %%
# Annualized Sharpe Ratios
sharpe_ratios = ((rfr_and_all_returns_df.mean()-rfr_and_all_returns_df['Risk-Free Rate'].mean()) * 252) / (rfr_and_all_returns_df.std() * np.sqrt(252))
 

# Create dataframe based on Sharpe calcs on the rfr_and_all_returns_df, set column name to Sharpe Ratio
sharpe_df = pd.DataFrame(sharpe_ratios,columns=['Sharpe Ratio'])
#Rename index column to be descriptive
sharpe_df.index.name = 'Firm'

#Sort
sharpe_df.sort_values('Sharpe Ratio',ascending=True,inplace=True)
#Check
sharpe_df
# Out:
#                              Sharpe Ratio
# Firm
# PAULSON & CO.INC.               -0.703093
# TIGER GLOBAL MANAGEMENT LLC     -0.280734
# Risk-Free Rate                   0.000000
# SOROS FUND MANAGEMENT LLC        0.203632
# Algo 2                           0.314133
# S&P 500 Returns                  0.492225
# BERKSHIRE HATHAWAY INC           0.521263
# Algo 1                           1.147535

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_df.plot(kind='bar', title='Portfolio Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Portfolio Sharpe Ratios'}, xlabel='Firm'>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# In terms of Sharpe Ratios, Algo 1 outperforms the market (1.14 vs 0.49), however Algo 2 underperforms the broader market (0.31).

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
crm_close = Path('Resources/crm_close.csv')
crm_close_df = pd.read_csv(crm_close)
crm_close_df.set_index(pd.to_datetime(crm_close_df['Date'], infer_datetime_format=True),inplace=True)
crm_close_df.drop(columns=['Date'],inplace=True)
crm_close_df.columns = ['CRM']
#crm_close_df.head(3)

# %%
# Reading data from 2nd stock
cost_close = Path('Resources/cost_close.csv')
cost_close_df = pd.read_csv(cost_close)

cost_close_df.set_index(pd.to_datetime(cost_close_df['Date'], infer_datetime_format=True),inplace=True)
cost_close_df.drop(columns=['Date'],inplace=True)
cost_close_df.columns = ['COST']
#cost_close_df.head(3)

# %%
# Reading data from 3rd stock
nflx_close = Path('Resources/nflx_close.csv')
nflx_close_df = pd.read_csv(nflx_close)

nflx_close_df.set_index(pd.to_datetime(nflx_close_df['Date'], infer_datetime_format=True),inplace=True)
nflx_close_df.drop(columns=['Date'],inplace=True)
nflx_close_df.columns = ['NFLX']
#nflx_close_df.head(3)

# %%
# Reading data from 4th stock
shop_close = Path('Resources/shop_close.csv')
shop_close_df = pd.read_csv(shop_close)

shop_close_df.set_index(pd.to_datetime(shop_close_df['Date'], infer_datetime_format=True),inplace=True)
shop_close_df.drop(columns=['Date'],inplace=True)
shop_close_df.columns = ['SHOP']
#shop_close_df.head(3)

# %%
# Combine all stocks in a single DataFrame
my_portfolio = pd.concat([crm_close_df, cost_close_df,nflx_close_df,shop_close_df],axis = 'columns',join = 'inner')
my_portfolio
# Out:
#                CRM    COST    NFLX   SHOP
# Date
# 2015-05-21   72.91  143.94   89.00   2.57
# 2015-05-22   75.01  143.68   88.84   2.83
# 2015-05-26   73.57  143.25   87.99   2.97
# 2015-05-27   73.95  145.42   89.86   2.75
# 2015-05-28   72.68  144.26   89.51   2.75
# ...            ...     ...     ...    ...
# 2019-12-24  163.25  294.23  333.20  39.94
# 2019-12-26  164.51  295.73  332.63  40.88
# 2019-12-27  164.98  294.11  329.09  40.80
# 2019-12-30  162.44  295.14  323.31  39.64
# 2019-12-31  162.64  293.92  323.57  39.76
#
# [1162 rows x 4 columns]

# %%
# Reset Date index
###done already?

# %%
# Reorganize portfolio data by having a column per symbol
###done already?

# %%
# Calculate daily returns
my_portfolio_returns = my_portfolio.pct_change()

# Drop NAs
my_portfolio_returns = my_portfolio_returns.dropna()

# Display sample data
my_portfolio_returns
# Out:
#                  CRM      COST      NFLX      SHOP
# Date
# 2015-05-22  0.028803 -0.001806 -0.001798  0.101167
# 2015-05-26 -0.019197 -0.002993 -0.009568  0.049470
# 2015-05-27  0.005165  0.015148  0.021252 -0.074074
# 2015-05-28 -0.017174 -0.007977 -0.003895  0.000000
# 2015-05-29  0.000963 -0.011576 -0.004022 -0.010909
# ...              ...       ...       ...       ...
# 2019-12-24 -0.002993  0.003137  0.000300  0.026471
# 2019-12-26  0.007718  0.005098 -0.001711  0.023535
# 2019-12-27  0.002857 -0.005478 -0.010642 -0.001957
# 2019-12-30 -0.015396  0.003502 -0.017564 -0.028431
# 2019-12-31  0.001231 -0.004134  0.000804  0.003027
#
# [1161 rows x 4 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/4, 1/4, 1/4, 1/4]

# Calculate portfolio return
portfolio_returns_wt = my_portfolio_returns.dot(weights)

# Display sample data
portfolio_returns_wt.head()
# Out:
# Date
# 2015-05-22    0.031591
# 2015-05-26    0.004428
# 2015-05-27   -0.008127
# 2015-05-28   -0.007261
# 2015-05-29   -0.006386
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_returns_final_df = pd.concat([portfolio_returns_wt,rfr_and_all_returns_df],axis = 'columns', join = 'inner')
all_returns_final_df

 # Use the `rename` function and set the `columns` parameter to a dictionary of new column names
all_returns_final_df = all_returns_final_df.rename(columns={0: "My Portfolio"})
all_returns_final_df.head(3)
# Out:
#             My Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-05-22      0.031591                   0.000542            0.000292
# 2015-05-26      0.004428                  -0.008718            0.000968
# 2015-05-27     -0.008127                   0.005536            0.003383
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-05-22                     0.000734                0.005268 -0.007780
# 2015-05-26                    -0.007167               -0.003362 -0.004471
# 2015-05-27                     0.005831                0.003505  0.000935
#
#               Algo 2  S&P 500 Returns  Risk-Free Rate
# Date
# 2015-05-22 -0.003892        -0.002234        0.000002
# 2015-05-26 -0.009913        -0.010282        0.000002
# 2015-05-27  0.010525         0.009163        0.000001

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_returns_final_df.dropna()
all_returns_final_df.head(3)
# Out:
#             My Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-05-22      0.031591                   0.000542            0.000292
# 2015-05-26      0.004428                  -0.008718            0.000968
# 2015-05-27     -0.008127                   0.005536            0.003383
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-05-22                     0.000734                0.005268 -0.007780
# 2015-05-26                    -0.007167               -0.003362 -0.004471
# 2015-05-27                     0.005831                0.003505  0.000935
#
#               Algo 2  S&P 500 Returns  Risk-Free Rate
# Date
# 2015-05-22 -0.003892        -0.002234        0.000002
# 2015-05-26 -0.009913        -0.010282        0.000002
# 2015-05-27  0.010525         0.009163        0.000001

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

# Create dataframe based on std calcs on the all_returns_df, set column name to StDev
std_df = pd.DataFrame(all_returns_final_df.std(),columns=['StDev'])
#Rename index column to be descriptive
std_df.index.name = 'Portfolio'

#Annualize
ann_std_df = std_df * np.sqrt(252)
ann_std_df
# Out:
#                                 StDev
# Portfolio
# My Portfolio                 0.257711
# SOROS FUND MANAGEMENT LLC    0.127590
# PAULSON & CO.INC.            0.113553
# TIGER GLOBAL MANAGEMENT LLC  0.176893
# BERKSHIRE HATHAWAY INC       0.209909
# Algo 1                       0.122510
# Algo 2                       0.134414
# S&P 500 Returns              0.137042
# Risk-Free Rate               0.001442

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_std_df = all_returns_final_df.rolling(window=21).std()

# Plot rolling standard deviation
rolling_std_df.plot(figsize = (15,8), title='21Day Rolling StDev of All Portfolios')
# Out:
# <Axes: title={'center': '21Day Rolling StDev of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
# Calculate the correlation
price_correlation_final = all_returns_final_df.corr()
sns.heatmap(price_correlation_final, vmin=-1, vmax=1,center=0)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# Calculate covariance of a single portfolio
my_cov = all_returns_final_df['My Portfolio'].cov(all_returns_final_df['S&P 500 Returns'])

# Calculate variance of S&P 500
sp500_var = all_returns_final_df['S&P 500 Returns'].var()

# Computing beta (cov/var = beta)
my_beta = my_cov / sp500_var
my_beta

## Plot beta trend
#Calc rolling cov and var
roll_my_cov = all_returns_final_df['My Portfolio'].rolling(window=21).cov(all_returns_final_df['S&P 500 Returns'])
roll_sp500_var = all_returns_final_df['S&P 500 Returns'].rolling(window=21).var()

#Calc rolling beta and plot
roll_my_beta = roll_my_cov / roll_sp500_var
roll_my_beta.plot(title = '21Day Rolling Beta of My Portfolio',figsize = (8,5))
# Out:
# <Axes: title={'center': '21Day Rolling Beta of My Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
new_sharpe_ratios = ((all_returns_final_df.mean()-all_returns_final_df['Risk-Free Rate'].mean()) * 252) / (all_returns_final_df.std() * np.sqrt(252))

# Create dataframe based on Sharpe calcs on the rfr_and_all_returns_df, set column name to Sharpe Ratio
new_sharpe_df = pd.DataFrame(new_sharpe_ratios,columns=['Sharpe Ratio'])

#Rename index column to be descriptive
new_sharpe_df.index.name = 'Firm'

#Sort
new_sharpe_df.sort_values('Sharpe Ratio',ascending=True,inplace=True)
#Check
new_sharpe_df
# Out:
#                              Sharpe Ratio
# Firm
# PAULSON & CO.INC.               -0.827041
# TIGER GLOBAL MANAGEMENT LLC     -0.328708
# Risk-Free Rate                   0.000000
# SOROS FUND MANAGEMENT LLC        0.141659
# Algo 2                           0.293246
# S&P 500 Returns                  0.502019
# BERKSHIRE HATHAWAY INC           0.508817
# Algo 1                           1.146206
# My Portfolio                     1.455612

# %%
# Visualize the sharpe ratios as a bar plot
new_sharpe_df.plot(kind='bar')
# Out:
# <Axes: xlabel='Firm'>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# If the most important performance metric to us is the Sharpe Ratio, then my portfolio (equally weighted between Costco, Salesforce, Netflix, and Shopify) performs the best with a ratio of 1.45.
# Additionally, My Portfolio achieves a significantly greater return (plotted below) than any of the other options at roughly 320%, which is ~8x the S&P500 and just under 4x Algo 1's second place returns.
# It is also worth noting however that My Portfolio is much riskier than the others, with an Annualized StDev of about 26%, nearly double that of the S&P500. Thankfully, this data only goes until mid-2019... My Portfolio, with its concentration in tech or tech-adjacent names, would have faced a reckoning in more recent years.

# %%
 # Use the `cumprod` function to cumulatively multiply each element in the Series by it's preceding element until the end
cumulative_returns = (1 + all_returns_final_df).cumprod() - 1
cumulative_returns.plot(title='Cumulative Returns for All Portfolios', figsize=(12,6))
# Out:
# <Axes: title={'center': 'Cumulative Returns for All Portfolios'}, xlabel='Date'>
